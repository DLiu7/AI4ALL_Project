# %% [markdown]
# <a href="https://colab.research.google.com/github/DLiu7/AI4ALL_Project/blob/main/ai4all_9E_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 63.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 126.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 82.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 64.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 110.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO
# !yolo checks
# !wget https://github.com/ultralytics/assets/releases/tag/v8.3.0
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.169 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 42.3/235.7 GB disk)
#
# OS                  Linux-6.1.123+-x86_64-with-glibc2.35
# Environment         Colab
# Python              3.11.13
# Install             pip
# Path                /usr/local/lib/python3.11/dist-packages/ultralytics
# RAM                 12.67 GB
# Disk                42.3/235.7 GB
# CPU                 Intel Xeon 2.00GHz
# CPU count           2
# GPU                 Tesla T4, 15095MiB
# GPU count           1
# CUDA                12.4
#
# numpy               ✅ 2.0.2>=1.23.0
# matplotlib          ✅ 3.10.0>=3.3.0
# ...

# %%
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.9/86.9 kB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 10.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 56.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 34.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...

# %%
import os
from getpass import getpass
from roboflow import Roboflow

api_key = getpass("Enter Roboflow API Key: ")

# Set environment variable (optional but good practice)
os.environ["ROBOFLOW_API_KEY"] = api_key

# Use the key in Roboflow client
rf = Roboflow(api_key=api_key)

# Continue as normal
project = rf.workspace("datasets-pdabr").project("sard-8xjhy")
version = project.version(17)
dataset = version.download("yolov11")
# Out:
# Enter Roboflow API Key: ··········
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Sard-17 in yolov11:: 100%|██████████| 11522/11522 [00:03<00:00, 2992.66it/s]

# %%
#!yolo task=detect mode=train model=yolo11l.pt data={dataset.location}/data.yaml epochs=70 imgsz=640

# %%
import os
os.path.abspath("runs/detect/train5")

from ultralytics import YOLO
model = YOLO('best.pt')
#model.val(data="/content/Sard-17/data.yaml")

model.predict(source="/content/Sard-17/test/images", save=True, conf=0.25)
# Out:
# image 1/570 /content/Sard-17/test/images/gss1006_jpg.rf.32aa7f99ebd9eed1e6777ff5a3b64517.jpg: 640x640 1 human, 47.5ms
# image 2/570 /content/Sard-17/test/images/gss1006_jpg.rf.7420665da812a124c7a8cfd6f9d67bbe.jpg: 640x640 (no detections), 38.6ms
# image 3/570 /content/Sard-17/test/images/gss1006_jpg.rf.8ba83f6f0ac292da5003d3bcddd63f7a.jpg: 640x640 1 human, 38.6ms
# image 4/570 /content/Sard-17/test/images/gss1015_jpg.rf.0ffe8deefec932ca39ed0ce141726e51.jpg: 640x640 2 humans, 38.5ms
# image 5/570 /content/Sard-17/test/images/gss1015_jpg.rf.5ace33228d5369ea6bf22118f6a5dca6.jpg: 640x640 2 humans, 38.5ms
# image 6/570 /content/Sard-17/test/images/gss1015_jpg.rf.8a1644be346d5efbd5a9748bcaef8bb5.jpg: 640x640 2 humans, 32.0ms
# image 7/570 /content/Sard-17/test/images/gss1015_jpg.rf.9ada927b3321306afa1ade7709bb6ad8.jpg: 640x640 1 human, 27.5ms
# image 8/570 /content/Sard-17/test/images/gss1025_jpg.rf.3790fe6512d0b9901cd1eb91d2e9f38a.jpg: 640x640 3 humans, 27.6ms
# ...
